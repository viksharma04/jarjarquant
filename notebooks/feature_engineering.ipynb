# %%
import sys
import os
import numpy as np
import pandas as pd
import yfinance as yf

parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from jarjarquant import FeatureEngineering

# %%
spy = yf.Ticker("SPY")
df = spy.history(period='max', interval='1d')[['Open', 'High', 'Low', 'Close']]

# %%
fe = FeatureEngineering(features_df=df)

# %%
fe.fracDiff_FFD(d=0.75, thres=0.001).dropna().plot()
# Out:
# <Axes: xlabel='Date'>
